# %%
# %config Completer.use_jedi = False

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import folium
import requests
import json
import matplotlib as mpl
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
from geopy.geocoders import Nominatim

# %%
geolocator = Nominatim(user_agent='city_explorer')
location = geolocator.geocode('Manhattan, NY')
latitude = location.latitude
longitude = location.longitude
print(f'The geographical coordinates of Toronto are {latitude}, {longitude}')
# Out:
# The geographical coordinates of Toronto are 40.7896239, -73.9598939

# %%
CLIENTID = 'T10NG1UBRQCPQ0DFAHQCSLH30TUEH5YQXX2XEG51LXKXLR2Z'
CLIENTSECRET = 'WXWWRBQTNNFZ4LXWBQRZEDEGMYMWJEQSVDCULUZX4WRMTF1R'

# %%
url = 'https://api.foursquare.com/v2/venues/search'
categoryid = '4d4b7105d754a06374d81259'

params = dict(
client_id=CLIENTID,
client_secret=CLIENTSECRET,
v='20180323',
ll='{},{}'.format(latitude,longitude),
categoryId=categoryid,
limit=100
)
data = requests.get(url=url, params=params).json()
data['response'].keys()
# Out:
# dict_keys(['venues', 'confident'])

# %%
requests.get(url=url, params=params).url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=T10NG1UBRQCPQ0DFAHQCSLH30TUEH5YQXX2XEG51LXKXLR2Z&client_secret=WXWWRBQTNNFZ4LXWBQRZEDEGMYMWJEQSVDCULUZX4WRMTF1R&v=20180323&ll=40.7896239%2C-73.9598939&categoryId=4d4b7105d754a06374d81259&limit=100'

# %%
data
# Out:
# {'meta': {'code': 200, 'requestId': '60f97df6fdeef2506cd16b76'},
#  'response': {'venues': [{'id': '4c684d7473851b8dd845ba39',
#     'name': 'The Loeb Boathouse',
#     'contact': {},
#     'location': {'address': 'E 72nd St',
#      'crossStreet': 'Park Dr N',
#      'lat': 40.77528495950326,
#      'lng': -73.96878004074097,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.77528495950326,
#        'lng': -73.96878004074097}],
#      'distance': 1763,
#      'postalCode': '10028',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['E 72nd St (Park Dr N)',
#       'New York, NY 10028',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '60b10521d1481704c9d63fb8',
#     'name': '% Arabica',
#     'contact': {},
#     'location': {'address': '20 Old Fulton St',
#      'crossStreet': 'btwn Everit St & Elizabeth Pl',
#      'lat': 40.70272,
#      'lng': -73.994194,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70272,
#        'lng': -73.994194}],
#      'distance': 10097,
#      'postalCode': '11201',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['20 Old Fulton St (btwn Everit St & Elizabeth Pl)',
#       'New York, NY 11201',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '5890a1dc7ff1e4019025b42b',
#     'name': 'Daily Provisions',
#     'contact': {},
#     'location': {'address': '103 E 19th St',
#      'crossStreet': 'btwn Park Avenue S & Irving Pl',
#      'lat': 40.737719,
#      'lng': -73.987774,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.737719,
#        'lng': -73.987774},
#       {'label': 'entrance', 'lat': 40.737628, 'lng': -73.987679}],
#      'distance': 6237,
#      'postalCode': '10003',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['103 E 19th St (btwn Park Avenue S & Irving Pl)',
#       'New York, NY 10003',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'venuePage': {'id': '423510440'},
#     'hereNow': {'count': 2,
#      'summary': '2 people are here',
#      'groups': [{'type': 'others',
#        'name': 'Other people here',
#        'count': 2,
#        'items': []}]},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '5b3cdc52c9a517002c585380',
#     'name': 'Blue Bottle Coffee',
#     'contact': {},
#     'location': {'address': '76 N 4 St',
#      'crossStreet': 'at Berry St',
#      'lat': 40.716913,
#      'lng': -73.961039,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.716913,
#        'lng': -73.961039}],
#      'distance': 8094,
#      'postalCode': '11249',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['76 N 4 St (at Berry St)',
#       'Brooklyn, NY 11249',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 2,
#      'summary': '2 people are here',
#      'groups': [{'type': 'others',
#        'name': 'Other people here',
#        'count': 2,
#        'items': []}]},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '598abd6904d1ae59d5a6264f',
#     'name': 'Sey Coffee',
#     'contact': {},
#     'location': {'address': '18 Grattan St',
#      'lat': 40.70546381677077,
#      'lng': -73.93259539308113,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70546381677077,
#        'lng': -73.93259539308113}],
#      'distance': 9647,
#      'postalCode': '11206',
#      'cc': 'US',
#      'neighborhood': 'East Williamsburg',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['18 Grattan St',
#       'Brooklyn, NY 11206',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '2087411',
#      'url': 'https://www.seamless.com/menu/sey-coffee-18-grattan-street-brooklyn/2087411?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2087411',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'venuePage': {'id': '441692918'},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4fd4b271e4b01a812347decb',
#     'name': "Norma's",
#     'contact': {},
#     'location': {'address': '59-02 Catalpa Ave',
#      'crossStreet': 'at Forest Ave',
#      'lat': 40.7024091418764,
#      'lng': -73.90084505081177,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7024091418764,
#        'lng': -73.90084505081177}],
#      'distance': 10911,
#      'postalCode': '11385',
#      'cc': 'US',
#      'city': 'Ridgewood',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['59-02 Catalpa Ave (at Forest Ave)',
#       'Ridgewood, NY 11385',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '56607aa1498e3181722bba58',
#     'name': 'Caffe Vita',
#     'contact': {},
#     'location': {'address': '576 Johnson Ave',
#      'crossStreet': 'Stewart Ave',
#      'lat': 40.708736,
#      'lng': -73.92519,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.708736,
#        'lng': -73.92519},
#       {'label': 'entrance', 'lat': 40.708803, 'lng': -73.92522}],
#      'distance': 9468,
#      'postalCode': '11237',
#      'cc': 'US',
#      'neighborhood': 'East Williamsburg',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['576 Johnson Ave (Stewart Ave)',
#       'Brooklyn, NY 11237',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '5ce5b1f1f5e9d7002c4ad547',
#     'name': 'Pastis',
#     'contact': {},
#     'location': {'address': '52 Gansevoort St',
#      'lat': 40.739488,
#      'lng': -74.007246,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.739488,
#        'lng': -74.007246}],
#      'distance': 6862,
#      'postalCode': '10014',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['52 Gansevoort St',
#       'New York, NY 10014',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10c941735',
#       'name': 'French Restaurant',
#       'pluralName': 'French Restaurants',
#       'shortName': 'French',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '2231484',
#      'url': 'https://www.seamless.com/menu/pastis-52-gansevoort-st-new-york/2231484?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2231484',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4bafaa5df964a52066153ce3',
#     'name': "Nathan's Famous",
#     'contact': {},
#     'location': {'address': '1310 Surf Ave',
#      'crossStreet': 'at Stillwell Ave',
#      'lat': 40.57546706646261,
#      'lng': -73.98147694724416,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.57546706646261,
#        'lng': -73.98147694724416}],
#      'distance': 23909,
#      'postalCode': '11224',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1310 Surf Ave (at Stillwell Ave)',
#       'Brooklyn, NY 11224',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16f941735',
#       'name': 'Hot Dog Joint',
#       'pluralName': 'Hot Dog Joints',
#       'shortName': 'Hot Dogs',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/hotdog_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '2096000',
#      'url': 'https://www.seamless.com/menu/nathans-famous-1310-surf-ave-brooklyn/2096000?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2096000',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'venuePage': {'id': '99833915'},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '5328a37f498e0fcd62614b29',
#     'name': 'The Smith',
#     'contact': {},
#     'location': {'address': '1150 Broadway',
#      'crossStreet': 'at W 27th St',
#      'lat': 40.744366270141605,
#      'lng': -73.9888527327952,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.744366270141605,
#        'lng': -73.9888527327952}],
#      'distance': 5598,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1150 Broadway (at W 27th St)',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d157941735',
#       'name': 'New American Restaurant',
#       'pluralName': 'New American Restaurants',
#       'shortName': 'New American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '339739',
#      'url': 'https://www.seamless.com/menu/the-smith---nomad---1150-broadway-1150-broadway-new-york/339739?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=339739',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '49f85cbbf964a520f26c1fe3',
#     'name': 'Mitsuwa Marketplace',
#     'contact': {},
#     'location': {'address': '595 River Rd',
#      'crossStreet': 'at Archer St',
#      'lat': 40.81625111476336,
#      'lng': -73.97998764962125,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.81625111476336,
#        'lng': -73.97998764962125},
#       {'label': 'entrance', 'lat': 40.816945, 'lng': -73.980323}],
#      'distance': 3413,
#      'postalCode': '07020',
#      'cc': 'US',
#      'city': 'Edgewater',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['595 River Rd (at Archer St)',
#       'Edgewater, NJ 07020',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '5b29281678782c0034879d48',
#     'name': 'Mercado Little Spain',
#     'contact': {},
#     'location': {'address': '10 Hudson Yards',
#      'lat': 40.75274001731029,
#      'lng': -74.00183575101391,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75274001731029,
#        'lng': -74.00183575101391},
#       {'label': 'entrance', 'lat': 40.752546, 'lng': -74.001085}],
#      'distance': 5418,
#      'postalCode': '10001',
#      'cc': 'US',
#      'neighborhood': 'Chelsea',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['10 Hudson Yards',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'venuePage': {'id': '535697980'},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4c5ef77bfff99c74eda954d3',
#     'name': 'Eataly Flatiron',
#     'contact': {},
#     'location': {'address': '200 5th Ave',
#      'crossStreet': 'at W 23rd St',
#      'lat': 40.74198696405861,
#      'lng': -73.98991319280194,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74198696405861,
#        'lng': -73.98991319280194}],
#      'distance': 5875,
#      'postalCode': '10010',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['200 5th Ave (at W 23rd St)',
#       'New York, NY 10010',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f5941735',
#       'name': 'Gourmet Shop',
#       'pluralName': 'Gourmet Shops',
#       'shortName': 'Gourmet',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '2150992',
#      'url': 'https://www.seamless.com/menu/eataly-nyc-flatiron-200-5th-ave-new-york/2150992?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2150992',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '5e5454fd0906ab000b3f9b53',
#     'name': 'Levain Bakery',
#     'contact': {},
#     'location': {'address': '340 Lafayette St',
#      'lat': 40.72614,
#      'lng': -73.9947,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72614,
#        'lng': -73.9947}],
#      'distance': 7652,
#      'postalCode': '10012',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['340 Lafayette St',
#       'New York, NY 10012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4eb13d68e5e8c0f5bd2fd983',
#     'name': 'Dominique Ansel Bakery',
#     'contact': {},
#     'location': {'address': '189 Spring St',
#      'crossStreet': 'btwn Sullivan & Thompson St',
#      'lat': 40.7251633496652,
#      'lng': -74.00297583591562,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7251633496652,
#        'lng': -74.00297583591562}],
#      'distance': 8042,
#      'postalCode': '10012',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['189 Spring St (btwn Sullivan & Thompson St)',
#       'New York, NY 10012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'venuePage': {'id': '43632227'},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '3fd66200f964a52070e91ee3',
#     'name': 'Balthazar',
#     'contact': {},
#     'location': {'address': '80 Spring St',
#      'crossStreet': 'at Crosby St',
#      'lat': 40.72272353497926,
#      'lng': -73.99816997062293,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72272353497926,
#        'lng': -73.99816997062293}],
#      'distance': 8116,
#      'postalCode': '10012',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['80 Spring St (at Crosby St)',
#       'New York, NY 10012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10c941735',
#       'name': 'French Restaurant',
#       'pluralName': 'French Restaurants',
#       'shortName': 'French',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'venuePage': {'id': '51338430'},
#     'hereNow': {'count': 2,
#      'summary': '2 people are here',
#      'groups': [{'type': 'others',
#        'name': 'Other people here',
#        'count': 2,
#        'items': []}]},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '5c13bf838afbe0002de55061',
#     'name': 'Starbucks Reserve Roastery',
#     'contact': {},
#     'location': {'address': '61 9th Ave',
#      'crossStreet': 'at W 15th St',
#      'lat': 40.74166158826782,
#      'lng': -74.00507982765883,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74166158826782,
#        'lng': -74.00507982765883}],
#      'distance': 6558,
#      'postalCode': '10011',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['61 9th Ave (at W 15th St)',
#       'New York, NY 10011',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '594277b586f4cc0f251fc389',
#     'name': 'DeKalb Market Hall',
#     'contact': {},
#     'location': {'address': '445 Albee Sq',
#      'lat': 40.69107603298046,
#      'lng': -73.98282408714293,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.69107603298046,
#        'lng': -73.98282408714293}],
#      'distance': 11139,
#      'postalCode': '11201',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['445 Albee Sq',
#       'Brooklyn, NY 11201',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '2528723',
#      'url': 'https://www.seamless.com/menu/teppan-territory---dekalb-market-hall-445-albee-square-west-brooklyn/2528723?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2528723',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4acbe67af964a52044c820e3',
#     'name': "Katz's Delicatessen",
#     'contact': {},
#     'location': {'address': '205 E Houston St',
#      'crossStreet': 'at Ludlow St',
#      'lat': 40.722312,
#      'lng': -73.987362,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.722312,
#        'lng': -73.987362}],
#      'distance': 7842,
#      'postalCode': '10002',
#      'cc': 'US',
#      'neighborhood': 'Lower East Side',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['205 E Houston St (at Ludlow St)',
#       'New York, NY 10002',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '83328',
#      'url': 'https://www.seamless.com/menu/katzs-delicatessen--205-e-houston-st-new-york/83328?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=83328',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'venuePage': {'id': '36639778'},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '5c5b91da475abd002c39f4f8',
#     'name': 'Happy Cow',
#     'contact': {},
#     'location': {'lat': 40.683025,
#      'lng': -73.97572,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.683025,
#        'lng': -73.97572}],
#      'distance': 11941,
#      'postalCode': '11217',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Brooklyn, NY 11217', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d3941735',
#       'name': 'Vegetarian / Vegan Restaurant',
#       'pluralName': 'Vegetarian / Vegan Restaurants',
#       'shortName': 'Vegetarian / Vegan',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4f80a632e4b0b2237c573865',
#     'name': "Dunkin'",
#     'contact': {},
#     'location': {'address': '387 Jay St',
#      'crossStreet': 'btwn Willoughby St & Fulton Mall',
#      'lat': 40.69194368549364,
#      'lng': -73.9870583238669,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 40.691981,
#        'lng': -73.987157},
#       {'label': 'display',
#        'lat': 40.69194368549364,
#        'lng': -73.9870583238669}],
#      'distance': 11112,
#      'postalCode': '11201',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['387 Jay St (btwn Willoughby St & Fulton Mall)',
#       'Brooklyn, NY 11201',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '1161912',
#      'url': 'https://www.seamless.com/menu/dunkin-387-jay-st-brooklyn/1161912?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1161912',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 1,
#      'summary': 'One other person is here',
#      'groups': [{'type': 'others',
#        'name': 'Other people here',
#        'count': 1,
#        'items': []}]},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '591eea6f6cf01a755db80c89',
#     'name': 'Starbucks',
#     'contact': {},
#     'location': {'address': '1411 Broadway',
#      'crossStreet': '40th',
#      'lat': 40.754292223412804,
#      'lng': -73.98704612024362,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.754292223412804,
#        'lng': -73.98704612024362}],
#      'distance': 4550,
#      'postalCode': '10018',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1411 Broadway (40th)',
#       'New York, NY 10018',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '579c12cd498e6e815b3acf50',
#     'name': 'Eataly Downtown',
#     'contact': {},
#     'location': {'address': '101 Liberty St',
#      'crossStreet': 'btwn Church & Greenwich St',
#      'lat': 40.710075,
#      'lng': -74.011976,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.710075,
#        'lng': -74.011976},
#       {'label': 'entrance', 'lat': 40.710051, 'lng': -74.012128}],
#      'distance': 9884,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['101 Liberty St (btwn Church & Greenwich St)',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f5941735',
#       'name': 'Gourmet Shop',
#       'pluralName': 'Gourmet Shops',
#       'shortName': 'Gourmet',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '2151287',
#      'url': 'https://www.seamless.com/menu/eataly-nyc-downtown-101-liberty-st-floor-3-new-york/2151287?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2151287',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '5cd0190f3af988002c46b0c0',
#     'name': 'Essex Market',
#     'contact': {},
#     'location': {'address': '88 Essex St',
#      'crossStreet': 'at Delancey St',
#      'lat': 40.71802545259831,
#      'lng': -73.98824699849924,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71802545259831,
#        'lng': -73.98824699849924}],
#      'distance': 8321,
#      'postalCode': '10002',
#      'cc': 'US',
#      'neighborhood': 'Lower East Side',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['88 Essex St (at Delancey St)',
#       'New York, NY 10002',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '2235653',
#      'url': 'https://www.seamless.com/menu/essex-squeeze-88-essex-st-new-york/2235653?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2235653',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4a19d1edf964a5205a7a1fe3',
#     'name': 'The Halal Guys',
#     'contact': {},
#     'location': {'address': 'W 53rd St',
#      'crossStreet': 'at 6th Ave',
#      'lat': 40.7617072001323,
#      'lng': -73.97924065589905,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7617072001323,
#        'lng': -73.97924065589905}],
#      'distance': 3509,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['W 53rd St (at 6th Ave)',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b79ff',
#       'name': 'Halal Restaurant',
#       'pluralName': 'Halal Restaurants',
#       'shortName': 'Halal',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/halal_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '2103218',
#      'url': 'https://www.seamless.com/menu/the-halal-guys-w-53rd--6-ave-new-york/2103218?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2103218',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'venuePage': {'id': '47491332'},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '5716655d498e23619f894ef0',
#     'name': 'TurnStyle Underground Market',
#     'contact': {},
#     'location': {'address': '1000 S 8th Ave',
#      'crossStreet': 'btwn 57th & 58th St',
#      'lat': 40.767081,
#      'lng': -73.982569,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.767081,
#        'lng': -73.982569}],
#      'distance': 3154,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1000 S 8th Ave (btwn 57th & 58th St)',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '1104490',
#      'url': 'https://www.seamless.com/menu/taheni-grill-at-turnstyle-market-1000-8th-ave-new-york/1104490?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1104490',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '5e2e1297738bcf0007bcc775',
#     'name': 'Krispy Kreme Flagship',
#     'contact': {},
#     'location': {'address': '1601 Broadway',
#      'crossStreet': 'W. 48th St',
#      'lat': 40.76033794115424,
#      'lng': -73.98493503631131,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76033794115424,
#        'lng': -73.98493503631131}],
#      'distance': 3883,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1601 Broadway (W. 48th St)',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '5362a2ae498e3b18c22334be',
#     'name': 'Hudson Eats',
#     'contact': {},
#     'location': {'address': '225 Liberty St',
#      'crossStreet': 'at S End Ave',
#      'lat': 40.712665971481435,
#      'lng': -74.0159010887146,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.712665971481435,
#        'lng': -74.0159010887146}],
#      'distance': 9782,
#      'postalCode': '10281',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['225 Liberty St (at S End Ave)',
#       'New York, NY 10281',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '2479469',
#      'url': 'https://www.seamless.com/menu/hudson-eats-230-vesey-street-new-york/2479469?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2479469',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'venuePage': {'id': '84987886'},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '583eed929526bc3d3e491401',
#     'name': 'Café Cotton Bean',
#     'contact': {},
#     'location': {'address': '1077 Bergen St',
#      'crossStreet': 'at Nostrand Ave',
#      'lat': 40.676133475628895,
#      'lng': -73.95032704051951,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.676133475628895,
#        'lng': -73.95032704051951},
#       {'label': 'entrance', 'lat': 40.676217, 'lng': -73.95043}],
#      'distance': 12659,
#      'postalCode': '11216',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1077 Bergen St (at Nostrand Ave)',
#       'Brooklyn, NY 11216',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '2097392',
#      'url': 'https://www.seamless.com/menu/cafe-cotton-bean-1077-bergen-street-brooklyn/2097392?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2097392',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 1,
#      'summary': 'One other person is here',
#      'groups': [{'type': 'others',
#        'name': 'Other people here',
#        'count': 1,
#        'items': []}]},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '520e0f34498e1c964d2c9ee6',
#     'name': 'Starbucks',
#     'contact': {},
#     'location': {'address': '625 8th Ave',
#      'crossStreet': 'at Port Authority Bus Terminal',
#      'lat': 40.75663838,
#      'lng': -73.99094694,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75663838,
#        'lng': -73.99094694},
#       {'label': 'entrance', 'lat': 40.756359, 'lng': -73.99063}],
#      'distance': 4509,
#      'postalCode': '10018',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['625 8th Ave (at Port Authority Bus Terminal)',
#       'New York, NY 10018',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4bbe4a11a8449c742cee8321',
#     'name': 'Penn Sushi',
#     'contact': {},
#     'location': {'address': '2 Pennsylvania Plaza',
#      'lat': 40.750085490425846,
#      'lng': -73.99309158325195,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.750085490425846,
#        'lng': -73.99309158325195}],
#      'distance': 5215,
#      'postalCode': '10121',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['2 Pennsylvania Plaza',
#       'New York, NY 10121',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '2231414',
#      'url': 'https://www.seamless.com/menu/penn-sushi-2-pennsylvania-plaza-new-york/2231414?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2231414',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '5c08721481635b002c0a5784',
#     'name': 'Fuku',
#     'contact': {},
#     'location': {'lat': 40.682972,
#      'lng': -73.97569,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.682972,
#        'lng': -73.97569}],
#      'distance': 11946,
#      'postalCode': '11217',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Brooklyn, NY 11217', 'United States']},
#     'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#       'name': 'Fried Chicken Joint',
#       'pluralName': 'Fried Chicken Joints',
#       'shortName': 'Fried Chicken',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
# ...
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'venuePage': {'id': '56755543'},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '547d03e3498eb32c879589da',
#     'name': 'Baekjeong NYC (Kang Ho Dong Baekjeong)',
#     'contact': {},
#     'location': {'address': '1 E 32nd St',
#      'crossStreet': 'at 5th Ave',
#      'lat': 40.74709879834891,
#      'lng': -73.98519423416221,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74709879834891,
#        'lng': -73.98519423416221},
#       {'label': 'entrance', 'lat': 40.747063, 'lng': -73.985067}],
#      'distance': 5192,
#      'postalCode': '10016',
#      'cc': 'US',
#      'neighborhood': 'Koreatown',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1 E 32nd St (at 5th Ave)',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '2159739',
#      'url': 'https://www.seamless.com/menu/baekjeong-nyc-1-e-32nd-st-new-york/2159739?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2159739',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4f298f3a771655080994d9db',
#     'name': 'Grace Street Cafe',
#     'contact': {},
#     'location': {'address': '17 W 32nd St',
#      'crossStreet': 'btwn Broadway & 5th Ave',
#      'lat': 40.74770777348895,
#      'lng': -73.98660781684485,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74770777348895,
#        'lng': -73.98660781684485}],
#      'distance': 5181,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['17 W 32nd St (btwn Broadway & 5th Ave)',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '2037887',
#      'url': 'https://www.seamless.com/menu/grace-street-coffee--desserts-17-w-32nd-st-new-york/2037887?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2037887',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'venuePage': {'id': '125087951'},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4de3e4effa7651589f21983d',
#     'name': "Mother's Ruin",
#     'contact': {},
#     'location': {'address': '18 Spring St',
#      'crossStreet': 'btwn Mott & Elizabeth St',
#      'lat': 40.721382,
#      'lng': -73.995059,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.721382,
#        'lng': -73.995059}],
#      'distance': 8154,
#      'postalCode': '10012',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['18 Spring St (btwn Mott & Elizabeth St)',
#       'New York, NY 10012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11e941735',
#       'name': 'Cocktail Bar',
#       'pluralName': 'Cocktail Bars',
#       'shortName': 'Cocktail',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '940633',
#      'url': 'https://www.seamless.com/menu/mothers-ruin-18-spring-st-new-york/940633?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=940633',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'venuePage': {'id': '55033775'},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '556f0aa3498e8a8ed3059191',
#     'name': 'Pig Beach',
#     'contact': {},
#     'location': {'address': '480 Union Street',
#      'lat': 40.679431480221716,
#      'lng': -73.98880959442909,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.679431480221716,
#        'lng': -73.98880959442909}],
#      'distance': 12506,
#      'postalCode': '11231',
#      'cc': 'US',
#      'neighborhood': 'Gowanus',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['480 Union Street',
#       'Brooklyn, NY 11231',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '5f5e1b49af65ef27d803a4f0',
#     'name': 'The Tyger',
#     'contact': {},
#     'location': {'address': '1 Howard St',
#      'crossStreet': 'Centre St',
#      'lat': 40.718835,
#      'lng': -73.99948,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.718835,
#        'lng': -73.99948}],
#      'distance': 8558,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1 Howard St (Centre St)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '2488929',
#      'url': 'https://www.seamless.com/menu/the-tyger-1-howard-st-new-york/2488929?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2488929',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '584067e6b50d521817d726a1',
#     'name': 'Canal Street Market',
#     'contact': {},
#     'location': {'address': '265 Canal St',
#      'crossStreet': 'Cortlandt Alley',
#      'lat': 40.71889041182096,
#      'lng': -74.00099432589256,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71889041182096,
#        'lng': -74.00099432589256}],
#      'distance': 8602,
#      'postalCode': '10013',
#      'cc': 'US',
#      'neighborhood': 'SoHo',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['265 Canal St (Cortlandt Alley)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f7941735',
#       'name': 'Flea Market',
#       'pluralName': 'Flea Markets',
#       'shortName': 'Flea Market',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/fleamarket_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '2476597',
#      'url': 'https://www.seamless.com/menu/lazy-sundaes-canal-st-market-261-canal-street-new-york/2476597?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2476597',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '5bf07de3bcbf7a002cd8d9f3',
#     'name': 'Japan Village',
#     'contact': {},
#     'location': {'address': '934 3rd Ave',
#      'crossStreet': 'btwn 35th & 36th St',
#      'lat': 40.65590374239456,
#      'lng': -74.00611007055633,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.65590374239456,
#        'lng': -74.00611007055633},
#       {'label': 'entrance', 'lat': 40.656022, 'lng': -74.006312}],
#      'distance': 15387,
#      'postalCode': '11232',
#      'cc': 'US',
#      'neighborhood': 'Greenwood Heights',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['934 3rd Ave (btwn 35th & 36th St)',
#       'Brooklyn, NY 11232',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': False,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '2047700',
#      'url': 'https://www.seamless.com/menu/japan-village-934-3rd-ave-brooklyn/2047700?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2047700',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '4e6e89b5d22daab469b62696',
#     'name': 'Catch',
#     'contact': {},
#     'location': {'address': '21 9th Ave',
#      'crossStreet': 'at W 13th St',
#      'lat': 40.740127,
#      'lng': -74.006202,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.740127,
#        'lng': -74.006202}],
#      'distance': 6753,
#      'postalCode': '10014',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['21 9th Ave (at W 13th St)',
#       'New York, NY 10014',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ce941735',
#       'name': 'Seafood Restaurant',
#       'pluralName': 'Seafood Restaurants',
#       'shortName': 'Seafood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '826626',
#      'url': 'https://www.seamless.com/menu/catch-nyc-21-9th-ave-new-york/826626?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=826626',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'venuePage': {'id': '145267622'},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False},
#    {'id': '40e74880f964a520150a1fe3',
#     'name': 'Shake Shack',
#     'contact': {},
#     'location': {'address': 'Madison Square Park',
#      'crossStreet': 'Madison Ave & E 23rd St',
#      'lat': 40.74148371088094,
#      'lng': -73.9882180094719,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74148371088094,
#        'lng': -73.9882180094719}],
#      'distance': 5866,
#      'postalCode': '10010',
#      'cc': 'US',
#      'neighborhood': 'Flatiron',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Madison Square Park (Madison Ave & E 23rd St)',
#       'New York, NY 10010',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16c941735',
#       'name': 'Burger Joint',
#       'pluralName': 'Burger Joints',
#       'shortName': 'Burgers',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#        'suffix': '.png'},
#       'primary': True}],
#     'verified': True,
#     'stats': {'tipCount': 0,
#      'usersCount': 0,
#      'checkinsCount': 0,
#      'visitsCount': 0},
#     'delivery': {'id': '698246',
#      'url': 'https://www.seamless.com/menu/shake-shack-23rd-st--madison-ave-new-york/698246?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=698246',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'beenHere': {'count': 0,
#      'lastCheckinExpiredAt': 0,
#      'marked': False,
#      'unconfirmedCount': 0},
#     'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#     'referralId': 'v-1626963446',
#     'venueChains': [],
#     'hasPerk': False}],
#   'confident': False}}

# %%
items = data['response']['venues']
items
# Out:
# [{'id': '4c684d7473851b8dd845ba39',
#   'name': 'The Loeb Boathouse',
#   'contact': {},
#   'location': {'address': 'E 72nd St',
#    'crossStreet': 'Park Dr N',
#    'lat': 40.77528495950326,
#    'lng': -73.96878004074097,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.77528495950326,
#      'lng': -73.96878004074097}],
#    'distance': 1763,
#    'postalCode': '10028',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['E 72nd St (Park Dr N)',
#     'New York, NY 10028',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d14e941735',
#     'name': 'American Restaurant',
#     'pluralName': 'American Restaurants',
#     'shortName': 'American',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '60b10521d1481704c9d63fb8',
#   'name': '% Arabica',
#   'contact': {},
#   'location': {'address': '20 Old Fulton St',
#    'crossStreet': 'btwn Everit St & Elizabeth Pl',
#    'lat': 40.70272,
#    'lng': -73.994194,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.70272,
#      'lng': -73.994194}],
#    'distance': 10097,
#    'postalCode': '11201',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['20 Old Fulton St (btwn Everit St & Elizabeth Pl)',
#     'New York, NY 11201',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '5890a1dc7ff1e4019025b42b',
#   'name': 'Daily Provisions',
#   'contact': {},
#   'location': {'address': '103 E 19th St',
#    'crossStreet': 'btwn Park Avenue S & Irving Pl',
#    'lat': 40.737719,
#    'lng': -73.987774,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.737719,
#      'lng': -73.987774},
#     {'label': 'entrance', 'lat': 40.737628, 'lng': -73.987679}],
#    'distance': 6237,
#    'postalCode': '10003',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['103 E 19th St (btwn Park Avenue S & Irving Pl)',
#     'New York, NY 10003',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'venuePage': {'id': '423510440'},
#   'hereNow': {'count': 2,
#    'summary': '2 people are here',
#    'groups': [{'type': 'others',
#      'name': 'Other people here',
#      'count': 2,
#      'items': []}]},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '5b3cdc52c9a517002c585380',
#   'name': 'Blue Bottle Coffee',
#   'contact': {},
#   'location': {'address': '76 N 4 St',
#    'crossStreet': 'at Berry St',
#    'lat': 40.716913,
#    'lng': -73.961039,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.716913,
#      'lng': -73.961039}],
#    'distance': 8094,
#    'postalCode': '11249',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['76 N 4 St (at Berry St)',
#     'Brooklyn, NY 11249',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 2,
#    'summary': '2 people are here',
#    'groups': [{'type': 'others',
#      'name': 'Other people here',
#      'count': 2,
#      'items': []}]},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '598abd6904d1ae59d5a6264f',
#   'name': 'Sey Coffee',
#   'contact': {},
#   'location': {'address': '18 Grattan St',
#    'lat': 40.70546381677077,
#    'lng': -73.93259539308113,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.70546381677077,
#      'lng': -73.93259539308113}],
#    'distance': 9647,
#    'postalCode': '11206',
#    'cc': 'US',
#    'neighborhood': 'East Williamsburg',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['18 Grattan St',
#     'Brooklyn, NY 11206',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'delivery': {'id': '2087411',
#    'url': 'https://www.seamless.com/menu/sey-coffee-18-grattan-street-brooklyn/2087411?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2087411',
#    'provider': {'name': 'seamless',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_seamless_20180129.png'}}},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'venuePage': {'id': '441692918'},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '4fd4b271e4b01a812347decb',
#   'name': "Norma's",
#   'contact': {},
#   'location': {'address': '59-02 Catalpa Ave',
#    'crossStreet': 'at Forest Ave',
#    'lat': 40.7024091418764,
#    'lng': -73.90084505081177,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.7024091418764,
#      'lng': -73.90084505081177}],
#    'distance': 10911,
#    'postalCode': '11385',
#    'cc': 'US',
#    'city': 'Ridgewood',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['59-02 Catalpa Ave (at Forest Ave)',
#     'Ridgewood, NY 11385',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '56607aa1498e3181722bba58',
#   'name': 'Caffe Vita',
#   'contact': {},
#   'location': {'address': '576 Johnson Ave',
#    'crossStreet': 'Stewart Ave',
#    'lat': 40.708736,
#    'lng': -73.92519,
#    'labeledLatLngs': [{'label': 'display', 'lat': 40.708736, 'lng': -73.92519},
#     {'label': 'entrance', 'lat': 40.708803, 'lng': -73.92522}],
#    'distance': 9468,
#    'postalCode': '11237',
#    'cc': 'US',
#    'neighborhood': 'East Williamsburg',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['576 Johnson Ave (Stewart Ave)',
#     'Brooklyn, NY 11237',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '5ce5b1f1f5e9d7002c4ad547',
#   'name': 'Pastis',
#   'contact': {},
#   'location': {'address': '52 Gansevoort St',
#    'lat': 40.739488,
#    'lng': -74.007246,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.739488,
#      'lng': -74.007246}],
#    'distance': 6862,
#    'postalCode': '10014',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['52 Gansevoort St',
#     'New York, NY 10014',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d10c941735',
#     'name': 'French Restaurant',
#     'pluralName': 'French Restaurants',
#     'shortName': 'French',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'delivery': {'id': '2231484',
#    'url': 'https://www.seamless.com/menu/pastis-52-gansevoort-st-new-york/2231484?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2231484',
#    'provider': {'name': 'seamless',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_seamless_20180129.png'}}},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '4bafaa5df964a52066153ce3',
#   'name': "Nathan's Famous",
#   'contact': {},
#   'location': {'address': '1310 Surf Ave',
#    'crossStreet': 'at Stillwell Ave',
#    'lat': 40.57546706646261,
#    'lng': -73.98147694724416,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.57546706646261,
#      'lng': -73.98147694724416}],
#    'distance': 23909,
#    'postalCode': '11224',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['1310 Surf Ave (at Stillwell Ave)',
#     'Brooklyn, NY 11224',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d16f941735',
#     'name': 'Hot Dog Joint',
#     'pluralName': 'Hot Dog Joints',
#     'shortName': 'Hot Dogs',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/hotdog_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'delivery': {'id': '2096000',
#    'url': 'https://www.seamless.com/menu/nathans-famous-1310-surf-ave-brooklyn/2096000?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2096000',
#    'provider': {'name': 'seamless',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_seamless_20180129.png'}}},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'venuePage': {'id': '99833915'},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '5328a37f498e0fcd62614b29',
#   'name': 'The Smith',
#   'contact': {},
#   'location': {'address': '1150 Broadway',
#    'crossStreet': 'at W 27th St',
#    'lat': 40.744366270141605,
#    'lng': -73.9888527327952,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.744366270141605,
#      'lng': -73.9888527327952}],
#    'distance': 5598,
#    'postalCode': '10001',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['1150 Broadway (at W 27th St)',
#     'New York, NY 10001',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d157941735',
#     'name': 'New American Restaurant',
#     'pluralName': 'New American Restaurants',
#     'shortName': 'New American',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'delivery': {'id': '339739',
#    'url': 'https://www.seamless.com/menu/the-smith---nomad---1150-broadway-1150-broadway-new-york/339739?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=339739',
#    'provider': {'name': 'seamless',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_seamless_20180129.png'}}},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '49f85cbbf964a520f26c1fe3',
#   'name': 'Mitsuwa Marketplace',
#   'contact': {},
#   'location': {'address': '595 River Rd',
#    'crossStreet': 'at Archer St',
#    'lat': 40.81625111476336,
#    'lng': -73.97998764962125,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.81625111476336,
#      'lng': -73.97998764962125},
#     {'label': 'entrance', 'lat': 40.816945, 'lng': -73.980323}],
#    'distance': 3413,
#    'postalCode': '07020',
#    'cc': 'US',
#    'city': 'Edgewater',
#    'state': 'NJ',
#    'country': 'United States',
#    'formattedAddress': ['595 River Rd (at Archer St)',
#     'Edgewater, NJ 07020',
#     'United States']},
#   'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#     'name': 'Supermarket',
#     'pluralName': 'Supermarkets',
#     'shortName': 'Supermarket',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '5b29281678782c0034879d48',
#   'name': 'Mercado Little Spain',
#   'contact': {},
#   'location': {'address': '10 Hudson Yards',
#    'lat': 40.75274001731029,
#    'lng': -74.00183575101391,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.75274001731029,
#      'lng': -74.00183575101391},
#     {'label': 'entrance', 'lat': 40.752546, 'lng': -74.001085}],
#    'distance': 5418,
#    'postalCode': '10001',
#    'cc': 'US',
#    'neighborhood': 'Chelsea',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['10 Hudson Yards',
#     'New York, NY 10001',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d120951735',
#     'name': 'Food Court',
#     'pluralName': 'Food Courts',
#     'shortName': 'Food Court',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'venuePage': {'id': '535697980'},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '4c5ef77bfff99c74eda954d3',
#   'name': 'Eataly Flatiron',
#   'contact': {},
#   'location': {'address': '200 5th Ave',
#    'crossStreet': 'at W 23rd St',
#    'lat': 40.74198696405861,
#    'lng': -73.98991319280194,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.74198696405861,
#      'lng': -73.98991319280194}],
#    'distance': 5875,
#    'postalCode': '10010',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['200 5th Ave (at W 23rd St)',
#     'New York, NY 10010',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1f5941735',
#     'name': 'Gourmet Shop',
#     'pluralName': 'Gourmet Shops',
#     'shortName': 'Gourmet',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'delivery': {'id': '2150992',
#    'url': 'https://www.seamless.com/menu/eataly-nyc-flatiron-200-5th-ave-new-york/2150992?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2150992',
#    'provider': {'name': 'seamless',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_seamless_20180129.png'}}},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '5e5454fd0906ab000b3f9b53',
#   'name': 'Levain Bakery',
#   'contact': {},
#   'location': {'address': '340 Lafayette St',
#    'lat': 40.72614,
#    'lng': -73.9947,
#    'labeledLatLngs': [{'label': 'display', 'lat': 40.72614, 'lng': -73.9947}],
#    'distance': 7652,
#    'postalCode': '10012',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['340 Lafayette St',
#     'New York, NY 10012',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d16a941735',
#     'name': 'Bakery',
#     'pluralName': 'Bakeries',
#     'shortName': 'Bakery',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '4eb13d68e5e8c0f5bd2fd983',
#   'name': 'Dominique Ansel Bakery',
#   'contact': {},
#   'location': {'address': '189 Spring St',
#    'crossStreet': 'btwn Sullivan & Thompson St',
#    'lat': 40.7251633496652,
#    'lng': -74.00297583591562,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.7251633496652,
#      'lng': -74.00297583591562}],
#    'distance': 8042,
#    'postalCode': '10012',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['189 Spring St (btwn Sullivan & Thompson St)',
#     'New York, NY 10012',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d16a941735',
#     'name': 'Bakery',
#     'pluralName': 'Bakeries',
#     'shortName': 'Bakery',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'venuePage': {'id': '43632227'},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '3fd66200f964a52070e91ee3',
#   'name': 'Balthazar',
#   'contact': {},
#   'location': {'address': '80 Spring St',
#    'crossStreet': 'at Crosby St',
#    'lat': 40.72272353497926,
#    'lng': -73.99816997062293,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.72272353497926,
#      'lng': -73.99816997062293}],
#    'distance': 8116,
#    'postalCode': '10012',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['80 Spring St (at Crosby St)',
#     'New York, NY 10012',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d10c941735',
#     'name': 'French Restaurant',
#     'pluralName': 'French Restaurants',
#     'shortName': 'French',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'venuePage': {'id': '51338430'},
#   'hereNow': {'count': 2,
#    'summary': '2 people are here',
#    'groups': [{'type': 'others',
#      'name': 'Other people here',
#      'count': 2,
#      'items': []}]},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '5c13bf838afbe0002de55061',
#   'name': 'Starbucks Reserve Roastery',
#   'contact': {},
#   'location': {'address': '61 9th Ave',
#    'crossStreet': 'at W 15th St',
#    'lat': 40.74166158826782,
#    'lng': -74.00507982765883,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.74166158826782,
#      'lng': -74.00507982765883}],
#    'distance': 6558,
#    'postalCode': '10011',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['61 9th Ave (at W 15th St)',
#     'New York, NY 10011',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '594277b586f4cc0f251fc389',
#   'name': 'DeKalb Market Hall',
#   'contact': {},
#   'location': {'address': '445 Albee Sq',
#    'lat': 40.69107603298046,
#    'lng': -73.98282408714293,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.69107603298046,
#      'lng': -73.98282408714293}],
#    'distance': 11139,
#    'postalCode': '11201',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['445 Albee Sq',
#     'Brooklyn, NY 11201',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d120951735',
#     'name': 'Food Court',
#     'pluralName': 'Food Courts',
#     'shortName': 'Food Court',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'delivery': {'id': '2528723',
#    'url': 'https://www.seamless.com/menu/teppan-territory---dekalb-market-hall-445-albee-square-west-brooklyn/2528723?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2528723',
#    'provider': {'name': 'seamless',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_seamless_20180129.png'}}},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '4acbe67af964a52044c820e3',
#   'name': "Katz's Delicatessen",
#   'contact': {},
#   'location': {'address': '205 E Houston St',
#    'crossStreet': 'at Ludlow St',
#    'lat': 40.722312,
#    'lng': -73.987362,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.722312,
#      'lng': -73.987362}],
#    'distance': 7842,
#    'postalCode': '10002',
#    'cc': 'US',
#    'neighborhood': 'Lower East Side',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['205 E Houston St (at Ludlow St)',
#     'New York, NY 10002',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1c5941735',
#     'name': 'Sandwich Place',
#     'pluralName': 'Sandwich Places',
#     'shortName': 'Sandwiches',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'delivery': {'id': '83328',
#    'url': 'https://www.seamless.com/menu/katzs-delicatessen--205-e-houston-st-new-york/83328?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=83328',
#    'provider': {'name': 'seamless',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_seamless_20180129.png'}}},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'venuePage': {'id': '36639778'},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '5c5b91da475abd002c39f4f8',
#   'name': 'Happy Cow',
#   'contact': {},
#   'location': {'lat': 40.683025,
#    'lng': -73.97572,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.683025,
#      'lng': -73.97572}],
#    'distance': 11941,
#    'postalCode': '11217',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['Brooklyn, NY 11217', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1d3941735',
#     'name': 'Vegetarian / Vegan Restaurant',
#     'pluralName': 'Vegetarian / Vegan Restaurants',
#     'shortName': 'Vegetarian / Vegan',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '4f80a632e4b0b2237c573865',
#   'name': "Dunkin'",
#   'contact': {},
#   'location': {'address': '387 Jay St',
#    'crossStreet': 'btwn Willoughby St & Fulton Mall',
#    'lat': 40.69194368549364,
#    'lng': -73.9870583238669,
#    'labeledLatLngs': [{'label': 'entrance',
#      'lat': 40.691981,
#      'lng': -73.987157},
#     {'label': 'display', 'lat': 40.69194368549364, 'lng': -73.9870583238669}],
#    'distance': 11112,
#    'postalCode': '11201',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['387 Jay St (btwn Willoughby St & Fulton Mall)',
#     'Brooklyn, NY 11201',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d148941735',
#     'name': 'Donut Shop',
#     'pluralName': 'Donut Shops',
#     'shortName': 'Donuts',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'delivery': {'id': '1161912',
#    'url': 'https://www.seamless.com/menu/dunkin-387-jay-st-brooklyn/1161912?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1161912',
#    'provider': {'name': 'seamless',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_seamless_20180129.png'}}},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 1,
#    'summary': 'One other person is here',
#    'groups': [{'type': 'others',
#      'name': 'Other people here',
#      'count': 1,
#      'items': []}]},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '591eea6f6cf01a755db80c89',
#   'name': 'Starbucks',
#   'contact': {},
#   'location': {'address': '1411 Broadway',
#    'crossStreet': '40th',
#    'lat': 40.754292223412804,
#    'lng': -73.98704612024362,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.754292223412804,
#      'lng': -73.98704612024362}],
#    'distance': 4550,
#    'postalCode': '10018',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['1411 Broadway (40th)',
#     'New York, NY 10018',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '579c12cd498e6e815b3acf50',
#   'name': 'Eataly Downtown',
#   'contact': {},
#   'location': {'address': '101 Liberty St',
#    'crossStreet': 'btwn Church & Greenwich St',
#    'lat': 40.710075,
#    'lng': -74.011976,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.710075,
#      'lng': -74.011976},
#     {'label': 'entrance', 'lat': 40.710051, 'lng': -74.012128}],
#    'distance': 9884,
#    'postalCode': '10007',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['101 Liberty St (btwn Church & Greenwich St)',
#     'New York, NY 10007',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1f5941735',
#     'name': 'Gourmet Shop',
#     'pluralName': 'Gourmet Shops',
#     'shortName': 'Gourmet',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'delivery': {'id': '2151287',
#    'url': 'https://www.seamless.com/menu/eataly-nyc-downtown-101-liberty-st-floor-3-new-york/2151287?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2151287',
#    'provider': {'name': 'seamless',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_seamless_20180129.png'}}},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '5cd0190f3af988002c46b0c0',
#   'name': 'Essex Market',
#   'contact': {},
#   'location': {'address': '88 Essex St',
#    'crossStreet': 'at Delancey St',
#    'lat': 40.71802545259831,
#    'lng': -73.98824699849924,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.71802545259831,
#      'lng': -73.98824699849924}],
#    'distance': 8321,
#    'postalCode': '10002',
#    'cc': 'US',
#    'neighborhood': 'Lower East Side',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['88 Essex St (at Delancey St)',
#     'New York, NY 10002',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d120951735',
#     'name': 'Food Court',
#     'pluralName': 'Food Courts',
#     'shortName': 'Food Court',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'delivery': {'id': '2235653',
#    'url': 'https://www.seamless.com/menu/essex-squeeze-88-essex-st-new-york/2235653?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2235653',
#    'provider': {'name': 'seamless',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_seamless_20180129.png'}}},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '4a19d1edf964a5205a7a1fe3',
#   'name': 'The Halal Guys',
#   'contact': {},
#   'location': {'address': 'W 53rd St',
#    'crossStreet': 'at 6th Ave',
#    'lat': 40.7617072001323,
#    'lng': -73.97924065589905,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.7617072001323,
#      'lng': -73.97924065589905}],
#    'distance': 3509,
#    'postalCode': '10019',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['W 53rd St (at 6th Ave)',
#     'New York, NY 10019',
#     'United States']},
#   'categories': [{'id': '52e81612bcbc57f1066b79ff',
#     'name': 'Halal Restaurant',
#     'pluralName': 'Halal Restaurants',
#     'shortName': 'Halal',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/halal_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'delivery': {'id': '2103218',
#    'url': 'https://www.seamless.com/menu/the-halal-guys-w-53rd--6-ave-new-york/2103218?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2103218',
#    'provider': {'name': 'seamless',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_seamless_20180129.png'}}},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'venuePage': {'id': '47491332'},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '5716655d498e23619f894ef0',
#   'name': 'TurnStyle Underground Market',
#   'contact': {},
#   'location': {'address': '1000 S 8th Ave',
#    'crossStreet': 'btwn 57th & 58th St',
#    'lat': 40.767081,
#    'lng': -73.982569,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.767081,
#      'lng': -73.982569}],
#    'distance': 3154,
#    'postalCode': '10019',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['1000 S 8th Ave (btwn 57th & 58th St)',
#     'New York, NY 10019',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d120951735',
#     'name': 'Food Court',
#     'pluralName': 'Food Courts',
#     'shortName': 'Food Court',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'delivery': {'id': '1104490',
#    'url': 'https://www.seamless.com/menu/taheni-grill-at-turnstyle-market-1000-8th-ave-new-york/1104490?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1104490',
#    'provider': {'name': 'seamless',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_seamless_20180129.png'}}},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '5e2e1297738bcf0007bcc775',
#   'name': 'Krispy Kreme Flagship',
#   'contact': {},
#   'location': {'address': '1601 Broadway',
#    'crossStreet': 'W. 48th St',
#    'lat': 40.76033794115424,
#    'lng': -73.98493503631131,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.76033794115424,
#      'lng': -73.98493503631131}],
#    'distance': 3883,
#    'postalCode': '10019',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['1601 Broadway (W. 48th St)',
#     'New York, NY 10019',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d148941735',
#     'name': 'Donut Shop',
#     'pluralName': 'Donut Shops',
#     'shortName': 'Donuts',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '5362a2ae498e3b18c22334be',
#   'name': 'Hudson Eats',
#   'contact': {},
#   'location': {'address': '225 Liberty St',
#    'crossStreet': 'at S End Ave',
#    'lat': 40.712665971481435,
#    'lng': -74.0159010887146,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.712665971481435,
#      'lng': -74.0159010887146}],
#    'distance': 9782,
#    'postalCode': '10281',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['225 Liberty St (at S End Ave)',
#     'New York, NY 10281',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d120951735',
#     'name': 'Food Court',
#     'pluralName': 'Food Courts',
#     'shortName': 'Food Court',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'delivery': {'id': '2479469',
#    'url': 'https://www.seamless.com/menu/hudson-eats-230-vesey-street-new-york/2479469?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2479469',
#    'provider': {'name': 'seamless',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_seamless_20180129.png'}}},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'venuePage': {'id': '84987886'},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '583eed929526bc3d3e491401',
#   'name': 'Café Cotton Bean',
#   'contact': {},
#   'location': {'address': '1077 Bergen St',
#    'crossStreet': 'at Nostrand Ave',
#    'lat': 40.676133475628895,
#    'lng': -73.95032704051951,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.676133475628895,
#      'lng': -73.95032704051951},
#     {'label': 'entrance', 'lat': 40.676217, 'lng': -73.95043}],
#    'distance': 12659,
#    'postalCode': '11216',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['1077 Bergen St (at Nostrand Ave)',
#     'Brooklyn, NY 11216',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'delivery': {'id': '2097392',
#    'url': 'https://www.seamless.com/menu/cafe-cotton-bean-1077-bergen-street-brooklyn/2097392?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2097392',
#    'provider': {'name': 'seamless',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_seamless_20180129.png'}}},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 1,
#    'summary': 'One other person is here',
#    'groups': [{'type': 'others',
#      'name': 'Other people here',
#      'count': 1,
#      'items': []}]},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '520e0f34498e1c964d2c9ee6',
#   'name': 'Starbucks',
#   'contact': {},
#   'location': {'address': '625 8th Ave',
#    'crossStreet': 'at Port Authority Bus Terminal',
#    'lat': 40.75663838,
#    'lng': -73.99094694,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.75663838,
#      'lng': -73.99094694},
#     {'label': 'entrance', 'lat': 40.756359, 'lng': -73.99063}],
#    'distance': 4509,
#    'postalCode': '10018',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['625 8th Ave (at Port Authority Bus Terminal)',
#     'New York, NY 10018',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '4bbe4a11a8449c742cee8321',
#   'name': 'Penn Sushi',
#   'contact': {},
#   'location': {'address': '2 Pennsylvania Plaza',
#    'lat': 40.750085490425846,
#    'lng': -73.99309158325195,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.750085490425846,
#      'lng': -73.99309158325195}],
#    'distance': 5215,
#    'postalCode': '10121',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['2 Pennsylvania Plaza',
#     'New York, NY 10121',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1d2941735',
#     'name': 'Sushi Restaurant',
#     'pluralName': 'Sushi Restaurants',
#     'shortName': 'Sushi',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'delivery': {'id': '2231414',
#    'url': 'https://www.seamless.com/menu/penn-sushi-2-pennsylvania-plaza-new-york/2231414?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2231414',
#    'provider': {'name': 'seamless',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_seamless_20180129.png'}}},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '5c08721481635b002c0a5784',
#   'name': 'Fuku',
#   'contact': {},
#   'location': {'lat': 40.682972,
#    'lng': -73.97569,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.682972,
#      'lng': -73.97569}],
#    'distance': 11946,
#    'postalCode': '11217',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['Brooklyn, NY 11217', 'United States']},
#   'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#     'name': 'Fried Chicken Joint',
#     'pluralName': 'Fried Chicken Joints',
#     'shortName': 'Fried Chicken',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '4de6dfbe88777d988186d7a3',
#   'name': 'Hot Pastrami Stand',
#   'contact': {},
#   'location': {'address': 'Left Field (Field Level)',
#    'crossStreet': 'Citi Field',
#    'lat': 40.75774954530571,
#    'lng': -73.84645521640778,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.75774954530571,
#      'lng': -73.84645521640778}],
#    'distance': 10200,
#    'cc': 'US',
#    'city': 'Flushing',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['Left Field (Field Level) (Citi Field)',
#     'Flushing, NY',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d14e941735',
#     'name': 'American Restaurant',
#     'pluralName': 'American Restaurants',
#     'shortName': 'American',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '4db1fecfcda14b702a52cec9',
#   'name': "Keith's Grill",
#   'contact': {},
#   'location': {'address': 'Citi Field',
#    'lat': 40.757474148817316,
#    'lng': -73.84665886988778,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.757474148817316,
#      'lng': -73.84665886988778}],
#    'distance': 10194,
#    'postalCode': '11368',
#    'cc': 'US',
#    'city': 'Corona',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['Citi Field', 'Corona, NY 11368', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d16c941735',
#     'name': 'Burger Joint',
#     'pluralName': 'Burger Joints',
#     'shortName': 'Burgers',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '5f81d3bbf7a41d259575c05b',
#   'name': 'Fan Fan Doughnuts',
#   'contact': {},
#   'location': {'address': '448 Lafayette Ave',
#    'crossStreet': 'Franklin Ave',
# ...
#    'lng': -73.96142999712337,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.71657114852416,
#      'lng': -73.96142999712337},
#     {'label': 'entrance', 'lat': 40.716552, 'lng': -73.961553}],
#    'distance': 8133,
#    'postalCode': '11249',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['113 N 3rd St (at Berry St)',
#     'Brooklyn, NY 11249',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d117941735',
#     'name': 'Beer Garden',
#     'pluralName': 'Beer Gardens',
#     'shortName': 'Beer Garden',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'delivery': {'id': '2133438',
#    'url': 'https://www.seamless.com/menu/radegast-hall-113-n-3rd-st-brooklyn/2133438?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2133438',
#    'provider': {'name': 'seamless',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_seamless_20180129.png'}}},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'venuePage': {'id': '56755543'},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '547d03e3498eb32c879589da',
#   'name': 'Baekjeong NYC (Kang Ho Dong Baekjeong)',
#   'contact': {},
#   'location': {'address': '1 E 32nd St',
#    'crossStreet': 'at 5th Ave',
#    'lat': 40.74709879834891,
#    'lng': -73.98519423416221,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.74709879834891,
#      'lng': -73.98519423416221},
#     {'label': 'entrance', 'lat': 40.747063, 'lng': -73.985067}],
#    'distance': 5192,
#    'postalCode': '10016',
#    'cc': 'US',
#    'neighborhood': 'Koreatown',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['1 E 32nd St (at 5th Ave)',
#     'New York, NY 10016',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d113941735',
#     'name': 'Korean Restaurant',
#     'pluralName': 'Korean Restaurants',
#     'shortName': 'Korean',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'delivery': {'id': '2159739',
#    'url': 'https://www.seamless.com/menu/baekjeong-nyc-1-e-32nd-st-new-york/2159739?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2159739',
#    'provider': {'name': 'seamless',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_seamless_20180129.png'}}},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '4f298f3a771655080994d9db',
#   'name': 'Grace Street Cafe',
#   'contact': {},
#   'location': {'address': '17 W 32nd St',
#    'crossStreet': 'btwn Broadway & 5th Ave',
#    'lat': 40.74770777348895,
#    'lng': -73.98660781684485,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.74770777348895,
#      'lng': -73.98660781684485}],
#    'distance': 5181,
#    'postalCode': '10001',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['17 W 32nd St (btwn Broadway & 5th Ave)',
#     'New York, NY 10001',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1d0941735',
#     'name': 'Dessert Shop',
#     'pluralName': 'Dessert Shops',
#     'shortName': 'Desserts',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'delivery': {'id': '2037887',
#    'url': 'https://www.seamless.com/menu/grace-street-coffee--desserts-17-w-32nd-st-new-york/2037887?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2037887',
#    'provider': {'name': 'seamless',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_seamless_20180129.png'}}},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'venuePage': {'id': '125087951'},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '4de3e4effa7651589f21983d',
#   'name': "Mother's Ruin",
#   'contact': {},
#   'location': {'address': '18 Spring St',
#    'crossStreet': 'btwn Mott & Elizabeth St',
#    'lat': 40.721382,
#    'lng': -73.995059,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.721382,
#      'lng': -73.995059}],
#    'distance': 8154,
#    'postalCode': '10012',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['18 Spring St (btwn Mott & Elizabeth St)',
#     'New York, NY 10012',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d11e941735',
#     'name': 'Cocktail Bar',
#     'pluralName': 'Cocktail Bars',
#     'shortName': 'Cocktail',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'delivery': {'id': '940633',
#    'url': 'https://www.seamless.com/menu/mothers-ruin-18-spring-st-new-york/940633?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=940633',
#    'provider': {'name': 'seamless',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_seamless_20180129.png'}}},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'venuePage': {'id': '55033775'},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '556f0aa3498e8a8ed3059191',
#   'name': 'Pig Beach',
#   'contact': {},
#   'location': {'address': '480 Union Street',
#    'lat': 40.679431480221716,
#    'lng': -73.98880959442909,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.679431480221716,
#      'lng': -73.98880959442909}],
#    'distance': 12506,
#    'postalCode': '11231',
#    'cc': 'US',
#    'neighborhood': 'Gowanus',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['480 Union Street',
#     'Brooklyn, NY 11231',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1df931735',
#     'name': 'BBQ Joint',
#     'pluralName': 'BBQ Joints',
#     'shortName': 'BBQ',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '5f5e1b49af65ef27d803a4f0',
#   'name': 'The Tyger',
#   'contact': {},
#   'location': {'address': '1 Howard St',
#    'crossStreet': 'Centre St',
#    'lat': 40.718835,
#    'lng': -73.99948,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.718835,
#      'lng': -73.99948}],
#    'distance': 8558,
#    'postalCode': '10013',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['1 Howard St (Centre St)',
#     'New York, NY 10013',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d142941735',
#     'name': 'Asian Restaurant',
#     'pluralName': 'Asian Restaurants',
#     'shortName': 'Asian',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'delivery': {'id': '2488929',
#    'url': 'https://www.seamless.com/menu/the-tyger-1-howard-st-new-york/2488929?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2488929',
#    'provider': {'name': 'seamless',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_seamless_20180129.png'}}},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '584067e6b50d521817d726a1',
#   'name': 'Canal Street Market',
#   'contact': {},
#   'location': {'address': '265 Canal St',
#    'crossStreet': 'Cortlandt Alley',
#    'lat': 40.71889041182096,
#    'lng': -74.00099432589256,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.71889041182096,
#      'lng': -74.00099432589256}],
#    'distance': 8602,
#    'postalCode': '10013',
#    'cc': 'US',
#    'neighborhood': 'SoHo',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['265 Canal St (Cortlandt Alley)',
#     'New York, NY 10013',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1f7941735',
#     'name': 'Flea Market',
#     'pluralName': 'Flea Markets',
#     'shortName': 'Flea Market',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/fleamarket_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'delivery': {'id': '2476597',
#    'url': 'https://www.seamless.com/menu/lazy-sundaes-canal-st-market-261-canal-street-new-york/2476597?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2476597',
#    'provider': {'name': 'seamless',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_seamless_20180129.png'}}},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '5bf07de3bcbf7a002cd8d9f3',
#   'name': 'Japan Village',
#   'contact': {},
#   'location': {'address': '934 3rd Ave',
#    'crossStreet': 'btwn 35th & 36th St',
#    'lat': 40.65590374239456,
#    'lng': -74.00611007055633,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.65590374239456,
#      'lng': -74.00611007055633},
#     {'label': 'entrance', 'lat': 40.656022, 'lng': -74.006312}],
#    'distance': 15387,
#    'postalCode': '11232',
#    'cc': 'US',
#    'neighborhood': 'Greenwood Heights',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['934 3rd Ave (btwn 35th & 36th St)',
#     'Brooklyn, NY 11232',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d111941735',
#     'name': 'Japanese Restaurant',
#     'pluralName': 'Japanese Restaurants',
#     'shortName': 'Japanese',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'delivery': {'id': '2047700',
#    'url': 'https://www.seamless.com/menu/japan-village-934-3rd-ave-brooklyn/2047700?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2047700',
#    'provider': {'name': 'seamless',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_seamless_20180129.png'}}},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '4e6e89b5d22daab469b62696',
#   'name': 'Catch',
#   'contact': {},
#   'location': {'address': '21 9th Ave',
#    'crossStreet': 'at W 13th St',
#    'lat': 40.740127,
#    'lng': -74.006202,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.740127,
#      'lng': -74.006202}],
#    'distance': 6753,
#    'postalCode': '10014',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['21 9th Ave (at W 13th St)',
#     'New York, NY 10014',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1ce941735',
#     'name': 'Seafood Restaurant',
#     'pluralName': 'Seafood Restaurants',
#     'shortName': 'Seafood',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'delivery': {'id': '826626',
#    'url': 'https://www.seamless.com/menu/catch-nyc-21-9th-ave-new-york/826626?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=826626',
#    'provider': {'name': 'seamless',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_seamless_20180129.png'}}},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'venuePage': {'id': '145267622'},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False},
#  {'id': '40e74880f964a520150a1fe3',
#   'name': 'Shake Shack',
#   'contact': {},
#   'location': {'address': 'Madison Square Park',
#    'crossStreet': 'Madison Ave & E 23rd St',
#    'lat': 40.74148371088094,
#    'lng': -73.9882180094719,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.74148371088094,
#      'lng': -73.9882180094719}],
#    'distance': 5866,
#    'postalCode': '10010',
#    'cc': 'US',
#    'neighborhood': 'Flatiron',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['Madison Square Park (Madison Ave & E 23rd St)',
#     'New York, NY 10010',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d16c941735',
#     'name': 'Burger Joint',
#     'pluralName': 'Burger Joints',
#     'shortName': 'Burgers',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'delivery': {'id': '698246',
#    'url': 'https://www.seamless.com/menu/shake-shack-23rd-st--madison-ave-new-york/698246?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=698246',
#    'provider': {'name': 'seamless',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_seamless_20180129.png'}}},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#   'referralId': 'v-1626963446',
#   'venueChains': [],
#   'hasPerk': False}]

# %%
venues = [(v['name'],v['location']['lat'],v['location']['lng'],\
              v['categories'][0]['name']) for v in items]
venues = pd.DataFrame(venues)
venues.columns = ['Name','Latitude','Longitude','Category']
venues
# Out:
#                                       Name   Latitude  Longitude  \
# 0                       The Loeb Boathouse  40.775285 -73.968780
# 1                                % Arabica  40.702720 -73.994194
# 2                         Daily Provisions  40.737719 -73.987774
# 3                       Blue Bottle Coffee  40.716913 -73.961039
# 4                               Sey Coffee  40.705464 -73.932595
# 5                                  Norma's  40.702409 -73.900845
# 6                               Caffe Vita  40.708736 -73.925190
# 7                                   Pastis  40.739488 -74.007246
# 8                          Nathan's Famous  40.575467 -73.981477
# 9                                The Smith  40.744366 -73.988853
# 10                     Mitsuwa Marketplace  40.816251 -73.979988
# 11                    Mercado Little Spain  40.752740 -74.001836
# 12                         Eataly Flatiron  40.741987 -73.989913
# 13                           Levain Bakery  40.726140 -73.994700
# 14                  Dominique Ansel Bakery  40.725163 -74.002976
# 15                               Balthazar  40.722724 -73.998170
# 16              Starbucks Reserve Roastery  40.741662 -74.005080
# 17                      DeKalb Market Hall  40.691076 -73.982824
# 18                     Katz's Delicatessen  40.722312 -73.987362
# 19                               Happy Cow  40.683025 -73.975720
# 20                                 Dunkin'  40.691944 -73.987058
# 21                               Starbucks  40.754292 -73.987046
# 22                         Eataly Downtown  40.710075 -74.011976
# 23                            Essex Market  40.718025 -73.988247
# 24                          The Halal Guys  40.761707 -73.979241
# 25            TurnStyle Underground Market  40.767081 -73.982569
# 26                   Krispy Kreme Flagship  40.760338 -73.984935
# 27                             Hudson Eats  40.712666 -74.015901
# 28                        Café Cotton Bean  40.676133 -73.950327
# 29                               Starbucks  40.756638 -73.990947
# 30                              Penn Sushi  40.750085 -73.993092
# 31                                    Fuku  40.682972 -73.975690
# 32                      Hot Pastrami Stand  40.757750 -73.846455
# 33                           Keith's Grill  40.757474 -73.846659
# 34                       Fan Fan Doughnuts  40.689115 -73.957107
# 35                       Jack’s Wife Freda  40.740896 -74.001431
# 36                         Time Out Market  40.703421 -73.992146
# 37                          Threes Brewing  40.679799 -73.982159
# 38                              Thai Diner  40.720739 -73.995631
# 39                     Tavern on the Green  40.772256 -73.977476
# 40              Radegast Hall & Biergarten  40.716571 -73.961430
# 41  Baekjeong NYC (Kang Ho Dong Baekjeong)  40.747099 -73.985194
# 42                       Grace Street Cafe  40.747708 -73.986608
# 43                           Mother's Ruin  40.721382 -73.995059
# 44                               Pig Beach  40.679431 -73.988810
# 45                               The Tyger  40.718835 -73.999480
# 46                     Canal Street Market  40.718890 -74.000994
# 47                           Japan Village  40.655904 -74.006110
# 48                                   Catch  40.740127 -74.006202
# 49                             Shake Shack  40.741484 -73.988218
#
#                          Category
# 0             American Restaurant
# 1                     Coffee Shop
# 2                            Café
# 3                     Coffee Shop
# 4                     Coffee Shop
# 5                            Café
# 6                     Coffee Shop
# 7               French Restaurant
# 8                   Hot Dog Joint
# 9         New American Restaurant
# 10                    Supermarket
# 11                     Food Court
# 12                   Gourmet Shop
# 13                         Bakery
# 14                         Bakery
# 15              French Restaurant
# 16                    Coffee Shop
# 17                     Food Court
# 18                 Sandwich Place
# 19  Vegetarian / Vegan Restaurant
# 20                     Donut Shop
# 21                    Coffee Shop
# 22                   Gourmet Shop
# 23                     Food Court
# 24               Halal Restaurant
# 25                     Food Court
# 26                     Donut Shop
# 27                     Food Court
# 28                    Coffee Shop
# 29                    Coffee Shop
# 30               Sushi Restaurant
# 31            Fried Chicken Joint
# 32            American Restaurant
# 33                   Burger Joint
# 34                     Donut Shop
# 35            American Restaurant
# 36                     Food Court
# 37                        Brewery
# 38                Thai Restaurant
# 39            American Restaurant
# 40                    Beer Garden
# 41              Korean Restaurant
# 42                   Dessert Shop
# 43                   Cocktail Bar
# 44                      BBQ Joint
# 45               Asian Restaurant
# 46                    Flea Market
# 47            Japanese Restaurant
# 48             Seafood Restaurant
# 49                   Burger Joint

# %%
venues['Category'].value_counts()
# Out:
# Coffee Shop                      8
# Food Court                       6
# American Restaurant              4
# Donut Shop                       3
# Gourmet Shop                     2
# Bakery                           2
# Burger Joint                     2
# Café                             2
# French Restaurant                2
# Fried Chicken Joint              1
# Hot Dog Joint                    1
# Asian Restaurant                 1
# Korean Restaurant                1
# Brewery                          1
# Vegetarian / Vegan Restaurant    1
# Cocktail Bar                     1
# Seafood Restaurant               1
# Thai Restaurant                  1
# Dessert Shop                     1
# Beer Garden                      1
# Sandwich Place                   1
# Halal Restaurant                 1
# BBQ Joint                        1
# New American Restaurant          1
# Japanese Restaurant              1
# Sushi Restaurant                 1
# Flea Market                      1
# Supermarket                      1
# Name: Category, dtype: int64

# %%
mpl.style.use('ggplot')
plt.figure(figsize=(16,7))
venues['Category'].value_counts().plot(kind='bar',color='steelblue')
plt.yticks(range(0,10))
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Count per Category')
plt.show()

# %%
citymap = folium.Map(location=[latitude,longitude],zoom_start=12)

colorarray = list(map(mpl.colors.rgb2hex,(mpl.cm.rainbow(np.linspace(0,1,len(venues['Category'].unique()))))))
colordf = pd.DataFrame(colorarray,index=venues['Category'].unique())

for lat,lng,name,cat in zip(venues['Latitude'],venues['Longitude'],venues['Name'],venues['Category']):
    if 1 == 1:# and cat == 'Coffee Shop':
        label = folium.Popup('{}, {}'.format(name,cat),parse_html=True)
        folium.CircleMarker(
            [lat,lng],
            radius=5,
            popup=label,
            color=colordf.loc[cat, 0],
            fill_color=colordf.loc[cat, 0],
            fill_opacity=0.7,
            parse_html=False
        ).add_to(citymap)


citymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f663d9c44ce34b449faf96bec5a8057c%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f663d9c44ce34b449faf96bec5a8057c%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f663d9c44ce34b449faf96bec5a8057c%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_f663d9c44ce34b449faf96bec5a8057c%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.7896239%2C%20-73.9598939%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
colorarray
# Out:
# ['#8000ff',
#  '#6e1cff',
#  '#5c38fd',
#  '#4856fb',
#  '#3670f8',
#  '#218cf4',
#  '#10a2f0',
#  '#04b9ea',
#  '#17cbe4',
#  '#2adddd',
#  '#3dead5',
#  '#50f4cc',
#  '#62fbc4',
#  '#76ffb9',
#  '#88ffaf',
#  '#9cfba4',
#  '#aef498',
#  '#c2ea8c',
#  '#d4dd80',
#  '#e8cb72',
#  '#fbb965',
#  '#ffa256',
#  '#ff8c49',
#  '#ff703a',
#  '#ff562c',
#  '#ff381c',
#  '#ff1c0e',
#  '#ff0000']

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\amoel.geogy\\Documents\\Coursera_Capstone_BattleofNeighborhoods'

# %%
import sys
import geojson
with open('manhattan.geojson') as f:
    gj = geojson.load(f)
features = gj['features']

# %%
features[0]['properties']['name']
# Out:
# 'Battery Park City'

# %%
man_json = json.loads('manhattan.geojson')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-380-b294b35dd7f7> in <module>
# ----> 1 man_json = json.loads('manhattan.geojson')
#
# c:\users\amoel.geogy\appdata\local\programs\python\python39\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# c:\users\amoel.geogy\appdata\local\programs\python\python39\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# c:\users\amoel.geogy\appdata\local\programs\python\python39\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
man_json
# Out:
# <_io.TextIOWrapper name='manhattan.geojson' mode='r' encoding='cp1252'>

# %%
features
# Out:
# {"geometry": {"coordinates": [[[[-74.013754, 40.71369], [-74.014262, 40.710928], [-74.016542, 40.704733], [-74.016174, 40.702572], [-74.01563, 40.701862], [-74.015127, 40.70139], [-74.014008, 40.701043], [-74.013959, 40.700966], [-74.014105, 40.700511], [-74.014091, 40.700508], [-74.014149, 40.700321], [-74.014221, 40.700111], [-74.01431, 40.700121], [-74.01431, 40.700134], [-74.014178, 40.700541], [-74.014165, 40.700539], [-74.014152, 40.700578], [-74.014289, 40.700644], [-74.014297, 40.700629], [-74.014315, 40.700611], [-74.01456, 40.70031], [-74.014633, 40.700197], [-74.014671, 40.70021], [-74.014667, 40.700239], [-74.014608, 40.700324], [-74.014324, 40.700661], [-74.014643, 40.700817], [-74.015068, 40.700318], [-74.015098, 40.700334], [-74.014674, 40.700835], [-74.014811, 40.700904], [-74.014828, 40.700895], [-74.015021, 40.700993], [-74.015142, 40.700843], [-74.015678, 40.701256], [-74.016139, 40.701646], [-74.016533, 40.702037], [-74.016819, 40.702339], [-74.017145, 40.702705], [-74.017252, 40.702836], [-74.017398, 40.703019], [-74.01744, 40.703078], [-74.01754, 40.703236], [-74.017575, 40.703308], [-74.017617, 40.703423], [-74.017626, 40.703423], [-74.017648, 40.703495], [-74.017671, 40.703606], [-74.017683, 40.703711], [-74.017673, 40.703712], [-74.017677, 40.703771], [-74.017674, 40.703834], [-74.017666, 40.703899], [-74.017658, 40.703933], [-74.017643, 40.703989], [-74.017654, 40.703998], [-74.017655, 40.70401], [-74.017644, 40.704022], [-74.017634, 40.704025], [-74.017627, 40.704024], [-74.01757, 40.704184], [-74.017795, 40.704235], [-74.017856, 40.704079], [-74.017751, 40.704055], [-74.017791, 40.703951], [-74.017818, 40.703938], [-74.017838, 40.703963], [-74.017808, 40.704032], [-74.017912, 40.704054], [-74.017943, 40.703973], [-74.017955, 40.703976], [-74.017844, 40.704242], [-74.018448, 40.704162], [-74.018668, 40.704435], [-74.018656, 40.704441], [-74.017516, 40.704581], [-74.017481, 40.704667], [-74.018043, 40.704628], [-74.018054, 40.70463], [-74.018065, 40.704636], [-74.018113, 40.704554], [-74.018863, 40.70472], [-74.018887, 40.704729], [-74.018926, 40.704774], [-74.019343, 40.706094], [-74.019123, 40.706976], [-74.019103, 40.707], [-74.019066, 40.707014], [-74.019033, 40.707013], [-74.018954, 40.706997], [-74.018946, 40.707018], [-74.018937, 40.707034], [-74.018909, 40.707064], [-74.018885, 40.707086], [-74.018859, 40.7071], [-74.018829, 40.707115], [-74.018796, 40.707128], [-74.018761, 40.707138], [-74.018726, 40.707143], [-74.01869, 40.707142], [-74.018655, 40.707142], [-74.018631, 40.70714], [-74.018581, 40.707124], [-74.018547, 40.707108], [-74.018571, 40.70708], [-74.018607, 40.707095], [-74.018644, 40.707105], [-74.018648, 40.707082], [-74.018687, 40.707084], [-74.018721, 40.707082], [-74.018751, 40.70708], [-74.018762, 40.707076], [-74.01875, 40.70705], [-74.018774, 40.707044], [-74.018794, 40.707032], [-74.01882, 40.707016], [-74.018848, 40.706983], [-74.018849, 40.70697], [-74.018811, 40.706966], [-74.018799, 40.706982], [-74.018776, 40.706997], [-74.018742, 40.707008], [-74.018679, 40.707019], [-74.018648, 40.707018], [-74.018628, 40.707011], [-74.018605, 40.706989], [-74.018572, 40.706938], [-74.018565, 40.706906], [-74.018549, 40.706908], [-74.018535, 40.706918], [-74.01853, 40.706951], [-74.018217, 40.707742], [-74.018217, 40.707751], [-74.01819, 40.707822], [-74.018656, 40.707924], [-74.018647, 40.707947], [-74.018801, 40.707981], [-74.018832, 40.707999], [-74.018853, 40.708022], [-74.018855, 40.708048], [-74.018608, 40.709135], [-74.017873, 40.712315], [-74.01777, 40.712835], [-74.017753, 40.712848], [-74.017732, 40.712849], [-74.01772, 40.712845], [-74.017721, 40.712784], [-74.0178, 40.712345], [-74.016625, 40.712157], [-74.016545, 40.712456], [-74.016592, 40.712548], [-74.016619, 40.71265], [-74.016618, 40.712756], [-74.016591, 40.712862], [-74.016555, 40.712929], [-74.016541, 40.712956], [-74.016477, 40.713029], [-74.016392, 40.7131], [-74.01632, 40.713408], [-74.016541, 40.713441], [-74. ...

# %%
type(l)
# Out:
# list

# %%
feat['properties']['name']
# Out:
# 'Battery Park City'

# %% [markdown]
# **Map the neighborhoods on Manhattan**

# %%
man_neigh_map = folium.Map(location=[latitude,longitude],zoom_start=12)
neighborhood_list = []
for feat in features:
    neighborhood_list.append(feat['properties']['name'])
    folium.GeoJson(feat,
                   ).add_to(man_neigh_map)
man_neigh_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_dddbcbf8b77a44e38746337ef055d80c%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_dddbcbf8b77a44e38746337ef055d80c%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_dddbcbf8b77a44e38746337ef055d80c%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_dddbcbf8b77a44e38746337ef055d80c%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.7896239%2C%20-73.9598939%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# **Get the neighborhood locations using geocoder**

# %%
dfneighborhoods = []
for neigh in neighborhood_list:
    cell = {}
    n_loc = geolocator.geocode('{}, Manhattan, New York, NY'.format(neigh))
    cell['Neighborhood'] = neigh
    cell['Latitude'] = n_loc.latitude
    cell['Longitude'] = n_loc.longitude
    dfneighborhoods.append(cell)
dfneighborhoods = pd.DataFrame(dc)
dfneighborhoods.head()
# Out:
#         Neighborhood   Latitude  Longitude
# 0  Battery Park City  40.711017 -74.016937
# 1       Central Park  40.782773 -73.965363
# 2            Chelsea  40.746491 -74.001528
# 3          Chinatown  40.716491 -73.996250
# 4       Civic Center  40.713679 -74.002404

# %% [markdown]
# **Now add the markers for each neighborhood to the map**

# %%
for lat,lon,neigh in zip(dfneighborhoods['Latitude'],dfneighborhoods['Longitude'],dfneighborhoods['Neighborhood']):
    folium.Marker(
        [lat,lon],
        popup=folium.Popup(neigh,parse_html=False)
    ).add_to(man_neigh_map)
    
man_neigh_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_dddbcbf8b77a44e38746337ef055d80c%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_dddbcbf8b77a44e38746337ef055d80c%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_dddbcbf8b77a44e38746337ef055d80c%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_dddbcbf8b77a44e38746337ef055d80c%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.7896239%2C%20-73.9598939%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
dfneighborhoods = []
for neigh in neighborhood_list:
    cell = {}
    n_loc = geolocator.geocode('{}, Manhattan, New York, NY'.format(neigh))
    cell['Neighborhood'] = neigh
    cell['Latitude'] = n_loc.latitude
    cell['Longitude'] = n_loc.longitude
    dc.append(cell)
dfneighborhoods = pd.DataFrame(dc)
dfneighborhoods
# Out:
#            Neighborhood   Latitude  Longitude
# 0     Battery Park City  40.711017 -74.016937
# 1          Central Park  40.782773 -73.965363
# 2               Chelsea  40.746491 -74.001528
# 3             Chinatown  40.716491 -73.996250
# 4          Civic Center  40.713679 -74.002404
# 5           East Harlem  40.794722 -73.942500
# 6          East Village  40.729269 -73.987361
# 7          Ellis Island  40.698594 -74.042014
# 8    Financial District  40.707668 -74.009271
# 9     Flatiron District  40.741072 -73.989653
# 10     Governors Island  40.688769 -74.018201
# 11             Gramercy  40.735519 -73.984079
# 12    Greenwich Village  40.733584 -74.002817
# 13               Harlem  40.807879 -73.945415
# 14       Hell's Kitchen  40.764423 -73.992392
# 15               Inwood  40.869258 -73.920495
# 16             Kips Bay  40.739546 -73.977083
# 17       Liberty Island  40.689814 -74.045139
# 18         Little Italy  40.719273 -73.998215
# 19      Lower East Side  40.715936 -73.986806
# 20          Marble Hill  40.876298 -73.910429
# 21              Midtown  40.760109 -73.978163
# 22  Morningside Heights  40.810000 -73.962500
# 23          Murray Hill  40.748157 -73.978750
# 24                 NoHo  40.725875 -73.993957
# 25               Nolita  40.720370 -73.994582
# 26     Randall's Island  40.791448 -73.921024
# 27     Roosevelt Island  40.761418 -73.950228
# 28                 SoHo  40.722880 -73.998750
# 29      Stuyvesant Town  40.731971 -73.978093
# 30     Theater District  40.757980 -73.985545
# 31              Tribeca  40.715380 -74.009306
# 32          Two Bridges  40.711288 -73.992233
# 33      Upper East Side  40.773702 -73.964120
# 34      Upper West Side  40.787045 -73.975416
# 35   Washington Heights  40.840198 -73.940221
# 36         West Village  40.734186 -74.005580

# %%
dfneighborhoods['Neighborhood'][0]
# Out:
# 'Battery Park City'

# %%
nmap = folium.Map(location=[n_lat,n_lon],zoom_start=15)
nmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_9800b16db54440ee88c1ef64958dc89e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_9800b16db54440ee88c1ef64958dc89e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_9800b16db54440ee88c1ef64958dc89e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_9800b16db54440ee88c1ef64958dc89e%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.7827725%2C%20-73.9653627406542%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
url = (
    "https://raw.githubusercontent.com/python-visualization/folium/master/examples/data"
)
antarctic_ice_edge = f"{url}/antarctic_ice_edge.json"
antarctic_ice_shelf_topo = f"{url}/antarctic_ice_shelf_topo.json"

# %%
antarctic_ice_shelf_topo
# Out:
# 'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data/antarctic_ice_shelf_topo.json'
